# %%
import pandas as pd

df = pd.read_feather('./experiment/data_to_analysis/scores_with_dimension_compressed.ftr')
df
# Out:
#                        match_no  player    win       pca      time  Mage  \
# 0         210513_na1_3902040674       7   True  0.558300  0.003728     1
# 1         210513_na1_3902040674       7   True  0.558342  0.004049     1
# 2         210513_na1_3902040674       4  False  0.872152  0.004466     0
# 3         210513_na1_3902040674       7   True  0.558388  0.004491     1
# 4         210513_na1_3902040674       6   True -1.041063  0.005179     0
# ...                         ...     ...    ...       ...       ...   ...
# 40534245   210517_jp1_302513885       7   True  0.571557  0.986911     1
# 40534246   210517_jp1_302513885       7   True  0.578548  0.987520     1
# 40534247   210517_jp1_302513885      10   True  0.104384  0.990790     0
# 40534248   210517_jp1_302513885       9   True  0.624859  0.991483     0
# 40534249   210517_jp1_302513885       7   True  0.590020  0.993949     1
#
#           Fighter  Support  Tank  Assassin  ...  ELITE_MONSTER_KILL  \
# ...

# %%
from matplotlib import pyplot as plt

models = df.columns[-7:]
print(models)

winner = df[df['win']==True].sample(20000)
loser = df[df['win']==False].sample(20000)

x_win = winner['pca'].to_numpy()
y_wins = [winner[model].to_numpy() for model in models]
x_lose = loser['pca'].to_numpy()
y_loses = [loser[model].to_numpy() for model in models]
# Out:
# Index(['normal', 'normal_bce', 'mlp_bce', 'zero_h0_bce', 'zero_h0_reverse',
#        'zero_h0', 'mlp'],
#       dtype='object')

# %%
i = 0 # Model 2
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 2')
plt.show()

# %%
i = 1 # Model 5
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 5')
plt.show()

# %%
i = 2 # Model 7
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 7')
plt.show()

# %%
i = 3 # Model 4
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 4')
plt.show()

# %%
i = 4 # Model 3
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 3')
plt.show()

# %%
i = 5 # Model 1
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 1')
plt.show()

# %%
i = 6 # Model 6
tmax = max(max(y_wins[i]), max(y_loses[i]))
tmin = min(min(y_wins[i]), min(y_loses[i]))
plt.yticks((tmin, tmax))
plt.xlabel('Dimension reductioned feature value')
plt.ylabel('Model score')
plt.scatter(x_win, y_wins[i], color=(0,0,1), s=2, alpha=0.5)
plt.scatter(x_lose, y_loses[i], color=(1,0,0), s=2, alpha=0.5)
plt.title('Model 6')
plt.show()
