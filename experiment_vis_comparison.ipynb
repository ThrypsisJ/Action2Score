# %%
import experiment_vis_functions as vis

vis.scores_per_event(save=False, model='spa')

# %%
import experiment_vis_functions as vis

vis.match_score_timeline(save=True, models=['spa'])

# %%
import experiment_vis_functions as vis

vis.score_by_position(save=False, event='CHAMPION_KILL', isWin=True, role='JUNGLE')
vis.score_by_position(save=False, event='CHAMPION_KILL', isWin=True, role='BOTTOM')
vis.score_by_position(save=False, event='CHAMPION_KILL_VICTIM', isWin=True, role='JUNGLE')
vis.score_by_position(save=False, event='CHAMPION_KILL_VICTIM', isWin=True, role='BOTTOM')
# Out:
# Loading datas...
# Slicing datas:  249/250 x,  249/250 y
# Loading datas...
# Slicing datas:  249/250 x,  249/250 y
# Loading datas...
# Slicing datas:  249/250 x,  249/250 y
# Loading datas...
# Slicing datas:  249/250 x,  249/250 y

# %%
import experiment_vis_functions as vis

vis.score_per_player(save=True, models=['spa'])

# %%
import experiment_vis_functions as vis

vis.score_hist2('CHAMPION_KILL_VICTIM', save=True, factor='time')

# %% [markdown]
# # ROC curve

# %%
import experiment_vis_functions as vis

vis.draw_roc_curve()

# %%
import experiment_vis_functions as vis

vis.score_factor_box_role(event='CHAMPION_KILL_VICTIM', save=False, factor='x_position', roles=['JUNGLE', 'BOTTOM'], sample=60000)
# Out:
# Loading datas...
# Creating figure...

# %%
import experiment_vis_functions as vis

fix_values = {
    'time': (0.10, 0.20),
    'x_position': (0.45, 0.55),
    'y_position': (0.45, 0.55),
    'deviation': (0.80, 1.00),
    'event_weight': (0.00, 1.00)
}

vis.score_factor_box_rnb(event='CHAMPION_KILL_VICTIM', location='JUNGLE', role='all', fix=fix_values, factor='time', sample=60000, save=False)
vis.score_factor_box_rnb(event='CHAMPION_KILL_VICTIM', location='BOTTOM', role='all', fix=fix_values, factor='time', sample=60000, save=False)
# Out:
# Loading datas...
# Creating figure...
# Loading datas...
# Creating figure...

# %%
import experiment_vis_functions as vis

# match_number = '210510_eun1_2825546524'
# match_number = '210510_euw1_5253755356' # too many WARD_PLACED
match_number = '210510_kr_5179842525'

vis.score_per_player(save=False, model='spa', match=match_number)
vis.score_per_player(save=False, model='spa', events=['BUILDING_KILL', 'BUILDING_KILL_ASSIST'], match=match_number)
vis.score_per_player(save=False, model='spa', events=['CHAMPION_KILL','CHAMPION_KILL_ASSIST'], match=match_number)
vis.score_per_player(save=False, model='spa', events=['ELITE_MONSTER_KILL', 'ELITE_MONSTER_KILL_ASSIST'], match=match_number)
vis.score_per_player(save=False, model='spa', events=['ITEM_PURCHASED', 'ITEM_DESTROYED'], match=match_number)

vis.score_of_player_per_event(save=False, model='spa', match=match_number, player=6)
# Out:
# Loading datas...
# 210510_kr_5179842525
# Creating plots...
# Loading datas...
# 210510_kr_5179842525
# Creating plots...
# Loading datas...
# 210510_kr_5179842525
# Creating plots...
# Loading datas...
# 210510_kr_5179842525
# Creating plots...
# Loading datas...
# 210510_kr_5179842525
# Creating plots...
# Loading datas...
# 210510_kr_5179842525
# Creating plots...

# %%
import experiment_vis_functions as vis
vis.box_per_event(False, 'spa')
vis.box_per_event(False, 'g2')
vis.box_per_event(False, 'ch')
vis.box_per_event(False, 'las')
# Out:
# Loading datas...
# Creating figure...
# Loading datas...
# Creating figure...
# Loading datas...
# Creating figure...
# Loading datas...
# Creating figure...
